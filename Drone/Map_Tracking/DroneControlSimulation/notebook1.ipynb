# %%
import ee
import ee
import matplotlib.pyplot as plt
import numpy as np

# %%
ee.Authenticate()
name = 'ee-firiusz123'
ee.Initialize(project=name)

print(ee.ImageCollection('COPERNICUS/S2').first().getInfo())
# Out:
# {'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [1830, 1830], 'crs': 'EPSG:32631', 'crs_transform': [60, 0, 300000, 0, -60, 3100020]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 300000, 0, -10, 3100020]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 300000, 0, -10, 3100020]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 300000, 0, -10, 3100020]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 300000, 0, -10, 3100020]}, {'id': 'B8A', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'B9', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [1830, 1830], 'crs': 'EPSG:32631', 'crs_transform': [60, 0, 300000, 0, -60, 3100020]}, {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [1830, 1830], 'crs': 'EPSG:32631', 'crs_transform': [60, 0, 300000, 0, -60, 3100020]}, {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'B12', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'QA10', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [10980, 10980], 'crs': 'EPSG:32631', 'crs_transform': [10, 0, 300000, 0, -10, 3100020]}, {'id': 'QA20', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 4294967295}, 'dimensions': [5490, 5490], 'crs': 'EPSG:32631', 'crs_transform': [20, 0, 300000, 0, -20, 3100020]}, {'id': 'QA60', 'data_type': {'type': 'PixelType', 'precision': 'int', 'min': 0, 'max': 65535}, 'dimensions': [1830, 1830], 'crs': 'EPSG:32631', 'crs_transform': [60, 0, 300000, 0, -60, 3100020]}], 'version': 1617875178877821, 'id': 'COPERNICUS/S2/20150627T102531_20160606T223605_T31RCL', 'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20150627T102537_000062_N02.02', 'SPACECRAFT_NAME': 'Sentinel-2A', 'FORMAT_CORRECTNESS_FLAG': 'PASSED', 'IERS_BULLETIN_FILENAME': 'S2__OPER_AUX_UT1UTC_PDMC_20150625T000000_V20150626T000000_20160625T000000', 'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 103.625932116468, 'MEAN_SOLAR_AZIMUTH_ANGLE': 98.2934185023958, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[2.0823420055272694, 28.022371475142155], [2.082262387713162, 28.022460994622374], [1.7870267921380452, 28.020172100522007], [1.7863863638768989, 28.019300827799174], [1.7840385788154567, 28.010599213518702], [1.7583696085580722, 27.9074708061136], [1.7138484027983951, 27.72807167221268], [1.711234871844144, 27.71720577206124], [1.711261139 ...

# %%
import ee
import matplotlib.pyplot as plt
import numpy as np
import requests
from PIL import Image
from io import BytesIO

# Step 1: Authenticate and initialize
ee.Authenticate()
ee.Initialize(project=name)

# Step 2: Define a smaller Area of Interest (AOI)
# Replace with your coordinates (longitude, latitude)
aoi = ee.Geometry.Point([19.1451, 51.9194])  # Example: Point in Poland

# Step 3: Get the image from the Sentinel-2 Image Collection with filters
image = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(aoi) \
    .filterDate('2023-01-01', '2023-01-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .first()  # Get the first image

# Step 4: Select RGB bands (B4, B3, B2 for Sentinel-2)
rgb_image = image.select(['B4', 'B3', 'B2'])

# Step 5: Get a URL to the image with reduced scale
url = rgb_image.getThumbUrl({'min': 0, 'max': 3000, 'scale': 100})  # Adjust scale to reduce size

# Step 6: Fetch the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Step 7: Convert the image to a numpy array
img_array = np.array(img)

# Step 8: Plot the image using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(img_array)
plt.axis('off')  # Turn off axis labels
plt.title('Satellite Image from Google Earth Engine')
plt.show()

# %%
import ee
import matplotlib.pyplot as plt
import numpy as np
import requests
from PIL import Image
from io import BytesIO

# Step 1: Authenticate and initialize
ee.Authenticate()
ee.Initialize(project=name)

# Step 2: Define a smaller Area of Interest (AOI)
# Example: Replace with a specific bounding box around a city or region
aoi = ee.Geometry.Rectangle([19.0, 51.8, 19.3, 52.0])  # Adjust the coordinates as needed

# Step 3: Get the image from the Sentinel-2 Image Collection with filters
image = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(aoi) \
    .filterDate('2023-01-01', '2023-01-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 5)) \
    .first()  # Get the first image

# Step 4: Select RGB bands (B4, B3, B2 for Sentinel-2)
rgb_image = image.select(['B4', 'B3', 'B2'])

# Step 5: Get a URL to the image with reduced scale for higher resolution
url = rgb_image.getThumbUrl({'min': 0, 'max': 3000, 'scale': 10})  # Adjust scale for higher resolution

# Step 6: Fetch the image from the URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Step 7: Convert the image to a numpy array
img_array = np.array(img)

# Step 8: Plot the image using Matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(img_array)
plt.axis('off')  # Turn off axis labels
plt.title('High-Resolution Satellite Image from Google Earth Engine')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:406, in _execute_cloud_call(call, num_retries)
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-firiusz123/thumbnails?fields=name&alt=json returned "Image.select: Parameter 'input' is required.". Details: "Image.select: Parameter 'input' is required.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[25], line 27
#      24 rgb_image = image.select(['B4', 'B3', 'B2'])
#      26 # Step 5: Get a URL to the image with reduced scale for higher resolution
# ---> 27 url = rgb_image.getThumbUrl({'min': 0, 'max': 3000, 'scale': 10})  # Adjust scale for higher resolution
#      29 # Step 6: Fetch the image from the URL
#      30 response = requests.get(url)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\deprecation.py:44, in Deprecated.<locals>.Decorator.<locals>.Wrapper(*args, **kwargs)
#      36 @functools.wraps(func)
#      37 def Wrapper(*args, **kwargs):
#      38   warnings.warn_explicit(
#      39       '%s() is deprecated: %s' % (func.__name__, message),
#      40       category=DeprecationWarning,
#      41       filename=func.__code__.co_filename,
#      42       lineno=func.__code__.co_firstlineno + 1,
#      43   )
# ---> 44   return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\image.py:562, in Image.getThumbURL(self, params)
#     538 """Get a thumbnail URL for this image.
#     539
#     540 Args:
#    (...)
#     557   EEException: If the region parameter is not an array or GeoJSON object.
#     558 """
#     559 # If the Cloud API is enabled, we can do cleaner handling of the parameters.
#     560 # If it isn't enabled, we have to be bug-for-bug compatible with current
#     561 # behaviour.
# --> 562 return data.makeThumbUrl(self.getThumbId(params))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\image.py:535, in Image.getThumbId(self, params)
#     533 image, params = image._apply_visualization(params)
#     534 params['image'] = image
# --> 535 return data.getThumbId(params)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:1246, in getThumbId(params, thumbType)
#    1242   request['filenamePrefix'] = params.get('name')
#    1243   request['bandIds'] = _cloud_api_utils.convert_to_band_list(
#    1244       params.get('bands')
#    1245   )
# -> 1246   result = _execute_cloud_call(
#    1247       _get_cloud_projects()
#    1248       .thumbnails()
#    1249       .create(parent=_get_projects_path(), **queryParams)
#    1250   )
#    1251 return {'thumbid': result['name'], 'token': ''}
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:408, in _execute_cloud_call(call, num_retries)
#     406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
# --> 408   raise _translate_cloud_exception(e)
#
# EEException: Image.select: Parameter 'input' is required.

# %%
import ee
import matplotlib.pyplot as plt
import numpy as np
import requests
from PIL import Image
from io import BytesIO

# Step 1: Authenticate and initialize
ee.Authenticate()
ee.Initialize(project=name)

# Step 2: Define the geometry for the area of interest (the rectangle)
geometry = ee.Geometry.Polygon(
    [[[19.90496095465271, 50.07236564089694],
      [19.90496095465271, 50.06744880132032],
      [19.917384946809694, 50.06744880132032],
      [19.917384946809694, 50.07236564089694]]], None, False)

# Step 3: Get the image from the Sentinel-2 Image Collection with filters
image_collection = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(geometry) \
    .filterDate('2023-01-01', '2023-01-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))  # Less than 10% cloud cover

# Get the first image
image = image_collection.first()

# Check if the image exists
if image is not None:
    # Select RGB bands (B4, B3, B2 for Sentinel-2)
    rgb_image = image.select(['B4', 'B3', 'B2'])

    # Get a URL to the image with reduced scale for higher resolution
    url = rgb_image.getThumbUrl({'min': 0, 'max': 3000, 'scale': 100})

    # Fetch the image from the URL
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))

    # Resize the image (optional)
    target_size = (800, 800)  # New size (width, height)
    resized_img = img.resize(target_size, Image.ANTIALIAS)

    # Convert the resized image to a numpy array
    img_array = np.array(resized_img)

    # Plot the resized image using Matplotlib
    plt.figure(figsize=(10, 10))
    plt.imshow(img_array)
    plt.axis('off')  # Turn off axis labels
    plt.title('Satellite Image of the Defined Area')
    plt.show()

else:
    print("No images found for the specified criteria.")
# Out:
# C:\Users\11\AppData\Local\Temp\ipykernel_15320\1665777025.py:42: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   resized_img = img.resize(target_size, Image.ANTIALIAS)

# %%
import ee
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Initialize the Earth Engine module
ee.Initialize(project=name)

# Define your rectangle geometry (replace with your coordinates)
rectangle = ee.Geometry.Rectangle([xmin, ymin, xmax, ymax])  # Adjust coordinates

# Create a Sentinel-2 image collection for a specific date range and area
sentinel2_collection = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(rectangle) \
    .filterDate('2022-01-01', '2022-12-31')  # Adjust date range as needed

# Select a single image (e.g., the first image in the collection)
sentinel2_image = sentinel2_collection.first()

# Select RGB bands
rgb_bands = sentinel2_image.select(['B4', 'B3', 'B2'])

# Define a region for the image and scale
region = rectangle.getInfo()['coordinates']
scale = 10  # Sentinel-2 has a resolution of 10 meters

# Get the image as a NumPy array
image_array = rgb_bands.reduceRegion(
    reducer=ee.Reducer.mean(),
    geometry=rectangle,
    scale=scale,
    maxPixels=1e13
).getInfo()

# Convert the image to a format compatible with Pillow
# Normalize the image values to be in the range of 0-255 for visualization
array = np.array([image_array['B4'], image_array['B3'], image_array['B2']]).transpose(1, 2, 0)
array = (array / np.max(array) * 255).astype(np.uint8)

# Create a PIL image and display it
image = Image.fromarray(array)
plt.imshow(image)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7 ee.Initialize(project=name)
#       9 # Define your rectangle geometry (replace with your coordinates)
# ---> 10 rectangle = ee.Geometry.Rectangle([xmin, ymin, xmax, ymax])  # Adjust coordinates
#      12 # Create a Sentinel-2 image collection for a specific date range and area
#      13 sentinel2_collection = ee.ImageCollection('COPERNICUS/S2') \
#      14     .filterBounds(rectangle) \
#      15     .filterDate('2022-01-01', '2022-12-31')  # Adjust date range as needed
#
# NameError: name 'xmin' is not defined

# %%
import ee
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from io import BytesIO

# Step 1: Authenticate and initialize Earth Engine
ee.Authenticate()
ee.Initialize()

# Step 2: Define the geometry for the area of interest (the rectangle)
geometry = ee.Geometry.Polygon(
    [[[19.90496095465271, 50.07236564089694],
      [19.90496095465271, 50.06744880132032],
      [19.917384946809694, 50.06744880132032],
      [19.917384946809694, 50.07236564089694]]])

# Step 3: Get the image from the Sentinel-2 Image Collection with filters
image_collection = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(geometry) \
    .filterDate('2023-01-01', '2023-01-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))  # Less than 10% cloud cover

# Get the first image
image = image_collection.first()

# Check if the image exists
if image:
    # Select RGB bands (B4, B3, B2 for Sentinel-2)
    rgb_image = image.select(['B4', 'B3', 'B2'])

    # Step 4: Get the URL for a 1200x800 pixel thumbnail image
    url = rgb_image.getThumbURL({
        'region': geometry,  # Define the region of interest
        'dimensions': '4500x2200',  # Image size (width x height)
        'format': 'png',  # Image format
        'min': 0,  # Minimum reflectance value
        'max': 3000,  # Maximum reflectance value
    })

    # Step 5: Fetch the image using the URL
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))

    # Convert the image to a numpy array
    img_array = np.array(img)

    # Step 6: Display the image using Matplotlib
    plt.figure(figsize=(10, 6))  # Aspect ratio 1200x800
    plt.imshow(img_array)
    plt.axis('off')  # Turn off axis labels
    plt.title('Sentinel-2 Image (1200x800)')
    plt.show()

else:
    print("No images found for the specified criteria.")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:406, in _execute_cloud_call(call, num_retries)
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/1002184025548/thumbnails?fields=name&alt=json returned "Total request size (59400000 bytes) must be less than or equal to 50331648 bytes.". Details: "Total request size (59400000 bytes) must be less than or equal to 50331648 bytes.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[9], line 33
#      30 rgb_image = image.select(['B4', 'B3', 'B2'])
#      32 # Step 4: Get the URL for a 1200x800 pixel thumbnail image
# ---> 33 url = rgb_image.getThumbURL({
#      34     'region': geometry,  # Define the region of interest
#      35     'dimensions': '4500x2200',  # Image size (width x height)
#      36     'format': 'png',  # Image format
#      37     'min': 0,  # Minimum reflectance value
#      38     'max': 3000,  # Maximum reflectance value
#      39 })
#      41 # Step 5: Fetch the image using the URL
#      42 response = requests.get(url)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\image.py:562, in Image.getThumbURL(self, params)
#     538 """Get a thumbnail URL for this image.
#     539
#     540 Args:
#    (...)
#     557   EEException: If the region parameter is not an array or GeoJSON object.
#     558 """
#     559 # If the Cloud API is enabled, we can do cleaner handling of the parameters.
#     560 # If it isn't enabled, we have to be bug-for-bug compatible with current
#     561 # behaviour.
# --> 562 return data.makeThumbUrl(self.getThumbId(params))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\image.py:535, in Image.getThumbId(self, params)
#     533 image, params = image._apply_visualization(params)
#     534 params['image'] = image
# --> 535 return data.getThumbId(params)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:1246, in getThumbId(params, thumbType)
#    1242   request['filenamePrefix'] = params.get('name')
#    1243   request['bandIds'] = _cloud_api_utils.convert_to_band_list(
#    1244       params.get('bands')
#    1245   )
# -> 1246   result = _execute_cloud_call(
#    1247       _get_cloud_projects()
#    1248       .thumbnails()
#    1249       .create(parent=_get_projects_path(), **queryParams)
#    1250   )
#    1251 return {'thumbid': result['name'], 'token': ''}
#
# File ~\AppData\Roaming\Python\Python310\site-packages\ee\data.py:408, in _execute_cloud_call(call, num_retries)
#     406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
# --> 408   raise _translate_cloud_exception(e)
#
# EEException: Total request size (59400000 bytes) must be less than or equal to 50331648 bytes.

# %%
import ee
import requests  # Add this if you haven't imported it already
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from io import BytesIO

# Step 1: Authenticate and initialize Earth Engine
ee.Authenticate()
ee.Initialize()

# Step 2: Define the geometry for the area of interest (the rectangle)
geometry = ee.Geometry.Polygon(
    [[[19.90496095465271, 50.07236564089694],
      [19.90496095465271, 50.06744880132032],
      [19.917384946809694, 50.06744880132032],
      [19.917384946809694, 50.07236564089694]]])

# Step 3: Get the image from the Sentinel-2 Image Collection with filters
image_collection = ee.ImageCollection('COPERNICUS/S2') \
    .filterBounds(geometry) \
    .filterDate('2023-01-01', '2023-01-31') \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))  # Less than 10% cloud cover

# Get the first image
image = image_collection.first()

# Check if the image exists
if image:
    # Select RGB bands (B4, B3, B2 for Sentinel-2)
    rgb_image = image.select(['B4', 'B3', 'B2'])

    # Step 4: Get the URL for the image using scale (10 meters per pixel)
    url = rgb_image.getThumbURL({
        'region': geometry,  # Define the region of interest
        'scale': 1,  # 10 meters per pixel (Sentinel-2 resolution)
        'format': 'png',  # Image format
        'min': 0,  # Minimum reflectance value
        'max': 2500,  # Adjusted maximum reflectance value to avoid saturation
    })

    # Step 5: Fetch the image from the URL
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))

    # Convert the image to a numpy array
    img_array = np.array(img)

    # Step 6: Display the image using Matplotlib
    plt.figure(figsize=(12, 8))  # Size in inches (this is 12x8 inches)
    plt.imshow(img_array)
    plt.axis('off')  # Turn off axis labels
    plt.title('Sentinel-2 Image at 10m per Pixel Resolution')

    # Step 7: Save the plot to a file with desired resolution
    plt.savefig('sentinel_image_rescaled.png', format='png', bbox_inches='tight', dpi=2300)  # Adjusted dpi for good quality

    plt.show()

else:
    print("No images found for the specified criteria.")
